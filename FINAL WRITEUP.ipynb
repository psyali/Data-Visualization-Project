# %% [markdown]
# #       FINAL   PROJECT   WRITEUP   -     TEAM   AWKWARD    ARMADILLOS

# %% [markdown]
#   In this project, we have used Python (Jupyter Notebook) for coding and creating visualizations required to be generated by the
#
#    codes and additionally, Tableau software for the creation of certain visualizations.

# %% [markdown]
# # 1) Why you took the approach you did?

# %% [markdown]
# •  We started with component 3 which involved generating the following components:
#
# •  A map of the United States, where the states are coloured either by the total sightings in each state over the selected time period, or the total time in sightings.
#
# •  A plot displaying the total number of sightings in whichever state is highlighted, aggregated so that it is a function of the year.
#
# •  A plot displaying the total duration of sightings in whichever state is highlighted, aggregated so that it is a function of the year.
#
# •  Tooltips should appear when hovering over the state with useful information about the state.
#
# •  We loaded the dataset into Jupyter with the given code.
#
# •  Next, we added the column for FIPS codes for all the states in United States of America contained in the dataset. We also split the “date” column to have a separate column for “years” in the dataset.
#
#
# •  The map of USA was generated using bqplot to display the total duration (in seconds) for the sightings in each state.
#
# •  Tooltip was applied to create a tooltip for when we hover the mouse over the name of the state along with the total number of sightings for the location.
#
#
# •  Further, a drop-down menu was generated to choose between the number of UFO sightings and the time of sightings.
#
# •  Then, we displayed a line chart for the total number of sightings and total duration of sightings for the highlighted state so that it aggregates as a function of the year and tested for the get_state_data function.
#
#
# •  To create the line chart, we first defined a and then, the type of selector. We used a fast interval selector.
#
# •  Next, we defined a function that will be called when the FastIntervalSelector interacts with it.
#
# •  Then we connected the selectors to that function and finally used the HTML widget to see the value of what we selected and accordingly modified it when an interaction was performed on the selector.
#
#
# •  The final part of this component required normalization based on a piece of information about the state.
#
# •  We picked the population for each state for this part. Here, we first read the .csv file in Jupyter Notebook and then used the separate column for FIPS code for each state.
#
# •  Data cleaning was required here as some states did not have values of population of the first year. Then we created a data frame whose column values are the state-wise population per year from the year 1906 to 2014.
#
#
# •  Then we proceeded to component 1 which involved working on the following components:
#
# •  The approach that I took for component 1 was to read in the location text file in the locations table. It then drops columns a and b which I have considered the last two redundant columns.
#
# •  Then we have set station as the index as it will be used for plotting the location of the different stations on the visualization.
#
# •  By setting the tohoku location and using the haversine formula, I have calculated the distance of each location from the tohoku location.
#
# •  This distance values are then sorted.
#
# •  The data_tohoku_norm_transpose data is read in the array_vals data frame and a time range of 4 hours is set with each observation differing by 1 sec.
#
# •  Normalization by replacing the NaN values by the mean is done
#
# •  Functions are written then to plot the spectrogram, slider, scatterplot.
#
# •  The interactions between all these functional graphs are done by importing libraries like boken,bqplot, IPython.display and many others.
#
# •  At the initial stage, this component required the location.txt file to be read into the Jupyter Notebook for the cleaning of irrelevant data (last two columns).
#
# •  Then we set station as the index as it was to be used for plotting the location of the different stations on the visualization.
#
# •  Here, we attempted to plot locations on the map where the earthquakes occurred. These locations are the latitude and longitude values from the location.txt.
#
#
# •  By setting the tohoku location and using the haversine formula, we have calculated the distance of each location from the tohoku location and sorted the values.
#
# •  The data_tohoku_norm_transpose data is read in the array_vals data frame and a time range of 4 hours is set with each observation differing by 1 sec. Normalization by replacing the NaN values by the mean was also carried out.
#
#
# •  Finally, we wrote appropriate functions to plot the spectrogram, slider, scatterplot. The interactions between all these functional graphs were done by importing libraries such as boken,bqplot, IPython.display, etc.

# %% [markdown]
# # Strengths of your approach?

# %% [markdown]
# • We began with a step-by-step approach that involved simply following the instructions stated in the project till
# we reached a point where it required decision-making on our part to create the visualization.
#
# It gave us a better understanding of the representation of the expected details from the dataset and slightly reduced
# ambiguity in the instructions for output generation.
#
# • The graphs are interactive and clearly indicate the changes due to the time values from the slider.
#
# • The visual representation will explain even a layman the idea about the project
#
# • The code is well arranged in functions for understanding.
#
# • There is a detailed explanation in terms of comments about what each section of the code does.

# %% [markdown]
# # Weakness of your approach?

# %% [markdown]
# •	We could not implement any method to deal with outliers and a mean value replacement of values is used to deal with NaN values.
#
# •	A large number of external libraries were used to implement the functions which initially lead to a lot of error generation in the codes.
#
# •	One of the downsides to having only three members in our group was that the completion of each task took a longer time than we had anticipated.

# %% [markdown]
# # Who in the group contributed each part of the visualization?

# %% [markdown]
# • All the group members contributed equally to the development of all the components.
#
# We consulted each other and held meetings at regular intervals to update each other on the progress of our respective components.
#
# The components were divided as follows:
#
#             • Sayali Tambe: First component
#
#             • Akanksha Aggarwal: Third component
#
#             • Suyash Singh: Fourth Component and creating tableau dashboard
#
# The preparation of the infographics involved inputs from all the members of the group as well. In addition to the infographics,
#
# we created a dashboard in Tableau software in the form of interactive visualizations displaying some useful analysis about the
#
# UFO sightings data which we attempted to integrate with our infographics as well.

# %% [markdown]
# # Additional work with Tableau for creating a visualization dashboard and infographic

# %% [markdown]
# UFO Tableau Dashboard
#
# Apart from the three components, we attempted to make an interactive dashboard in Tableau to analyze the
# different components of the dataset.
#
# We performed minor data cleaning using OpenRefine. The tableau workbook contains the following sheets:
#
#                             1. UFO Sightings
#
# •  We created projections of all the UFO sighting using the Country (US) filter.
#
# •  All the sightings are function of size, the bigger the size the more duration the ufo was sighted for
#
# •  We tried to match most of the shapes with the Tableau’s shapes but Tableau has only a limited number of shapes
#
# •  If you hover over the sightings on the map you will see the following details about that particular sightings
#
# i.   Latitude
#
# ii.  Longitude
#
# iii. State
#
# iv.  Shape
#
# v.   Year of Date Seen
#
# vi.  Duration
#
# vii. Description
#
# • The more you zoom into the map, the better it becomes to differentiate the shapes and sizes
#
#                             2. Year of Date Seen
#
# • The years of the date seen is shown as an Area Line Graph.
#
# • If you hover over the area or the tip of the line graph, you will see the following details
#
# i. Year of the Date Seen
#
# ii. Number of Records seen
#
#                             3. Shape (Bubble)
#
# The sheet projects all the shapes in the packed bubbles format.
#
# This would look comparatively better on the dashboard but given the constraint of space instead we used heat map for the same.
#
# • The size and the color of the bubbles are function of the total number of records of that particular shape.
#
#                             4. Shape (Heat Map)
#
#
#                             5. Duration
#
#
#                             6. States
#
#
#                             7. Time of Sightings
#
# The timings of the sightings are shown in a heat map by the function weekday and the hours of the day.
#
# We used the heat map as clear trends can be seen.
#
#                             Dashboard
#
# • The color of the dashboard is set to grey to go with the theme of the UFO dataset.
#
# • We used only four of the above mentioned sheets in the dashboard as they tend to show most of the information.
#
# • Additional dropdowns filters are added on the top left of the dashboard to add another layer of interactivity.

# %% [markdown]
# # Note: The Tableau (.twbx) file would only open in Tableau and the preferred version is Tableau v10.4

# %% [markdown]
# References:
#
#
#     https://blog.modeanalytics.com/python-interactive-plot-libraries/
#
#
#     https://plot.ly/python/
#
#
#     https://bokeh.pydata.org/en/latest/
#
#
#     https://stackoverflow.com/questions/4913349/haversine-formula-in-python-bearing-and-distance-between-two-gps-points
#
#
#     https://pypi.python.org/pypi/haversine
